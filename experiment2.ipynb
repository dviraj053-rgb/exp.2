# %%
# viraj
# Exp2 : Study of list in python
list1=["apple","orange","cherry"]
print(list1)
# Out:
# ['apple', 'orange', 'cherry']

# %%
list2=[2,2.5,"viraj",True,]
print(list2)
# Out:
# [2, 2.5, 'viraj', True]

# %%
list3=["apple","banana","orange","cherry","kiwi","mango",]
print(list3[2])
print(list3[-4])
print(list3[2:5])
print(list3[:5])
print(list3[2:])
print(len(list3))
# Out:
# orange
# orange
# ['orange', 'cherry', 'kiwi']
# ['apple', 'banana', 'orange', 'cherry', 'kiwi']
# ['orange', 'cherry', 'kiwi', 'mango']
# 6

# %%
list4=["apple","orange","cherry"]
list4[1]="mango"
print(list4)
# Out:
# ['apple', 'mango', 'cherry']

# %%
list5=["apple","orange","cherry"]
list5.append("mango")

print(list5)
# Out:
# ['apple', 'orange', 'cherry', 'mango']

# %%
list6=["apple","orange","cherry"]
list6.insert(1,"mango")
print(list6)
# Out:
# ['apple', 'mango', 'orange', 'cherry']

# %%
list7=["apple","banana","orange"]
list8=["kiwi","mango","cherry"]
list7.extend(list8)
print(list7)
# Out:
# ['apple', 'banana', 'orange', 'kiwi', 'mango', 'cherry']

# %%
list9=["apple","orange","apple","cherry"]
print(list9)
# Out:
# ['apple', 'orange', 'apple', 'cherry']

# %%
marks = [78, 85, 90, 66, 88]
"Maximum marks:"
"Minimum marks:"
"Total marks:"
"Number of students:"
"Calculate average marks"
"Sort the marks in ascending order"
print(max(marks))
print(min(marks))
print(len(marks))
print(sum(marks))
print(sum(marks)/len(marks))
marks.sort()
print(marks)
# Out:
# 90
# 66
# 5
# 407
# 81.4
# [66, 78, 85, 88, 90]

# %%
grocery_list = ("Rice", "Milk", "Eggs", "Bread", "Sugar")
print ("Grocery List:")
print (grocery_list)
grocery_list.append("01l")
grocery_list.append ("Fruits")
print("\nAfter adding new items:")
print (grocery_list)
grocery_list. remove("Milk0") grocery list. remove!("sugar")
print("\nAfter removing purchased items: ")
print (grocery_list)
print ("\nAccessing items using indexing:")
print ("InFinal Shopping List:”) for item in grocery_list:
print (item)
